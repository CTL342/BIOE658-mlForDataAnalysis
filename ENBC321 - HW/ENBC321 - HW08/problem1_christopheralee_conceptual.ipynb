# %% [markdown]
# Name: Christopher A. Lee\
# Date: 04/14/2026\
# Prof: Dr. Azarnoosh\
# Course: Machine Learning for Data Analysis - ENBC 321

# %%
print("1. Standardization is very important prior to PCA or k-means because of the sensitive nature that both algorithms \nhave to the scale of data.")
print("2. PCA reducing dimensionality means the transformation of a high dimensional dataset into a lower dimensional space. \nPCA preserves the directions in which maintains the maximum variance of a dataset. Interpretability can be harder due \nto the principal components being linear combinations of the original features.")
print("3. PCA can help reduce the noise present in the data, improve computational efficiency, and combat curse of dimensionality.")
print("4. Approximately 89.91 percent of the variance is explained by the first principal components You would decide if the \ntwo components are enough based on desired value, typically 80 to 90 percent.")
# Out:
# 1. Standardization is very important prior to PCA or k-means because of the sensitive nature that both algorithms
# have to the scale of data.
# 2. PCA reducing dimensionality means the transformation of a high dimensional dataset into a lower dimensional space.
# PCA preserves the directions in which maintains the maximum variance of a dataset. Interpretability can be harder due
# to the principal components being linear combinations of the original features.
# 3. PCA can help reduce the noise present in the data, improve computational efficiency, and combat curse of dimensionality.
# 4. Approximately 89.91 percent of the variance is explained by the first principal components You would decide if the
# two components are enough based on desired value, typically 80 to 90 percent.
